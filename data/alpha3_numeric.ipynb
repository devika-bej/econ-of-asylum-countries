# %%
import pandas as pd

# %%
df = pd.read_csv("https://gist.githubusercontent.com/tadast/8827699/raw/61b2107766d6fd51e2bd02d9f78f6be081340efc/countries_codes_and_coordinates.csv")
df.head()
# Out:
#           Country Alpha-2 code Alpha-3 code Numeric code Latitude (average)  \
# 0     Afghanistan         "AF"        "AFG"          "4"               "33"
# 1   Åland Islands         "AX"        "ALA"        "248"        "60.116667"
# 2         Albania         "AL"        "ALB"          "8"               "41"
# 3         Algeria         "DZ"        "DZA"         "12"               "28"
# 4  American Samoa         "AS"        "ASM"         "16"         "-14.3333"
#
#   Longitude (average)
# 0                "65"
# 1              "19.9"
# 2                "20"
# 3                 "3"
# 4              "-170"

# %%
df_new = df[['Numeric code', 'Alpha-3 code']]

df_new['Numeric code'] = df_new['Numeric code'].str.strip().str.replace('"', '')
df_new['Alpha-3 code'] = df_new['Alpha-3 code'].str.strip().str.replace('"', '')

df_new['Numeric code'] = df_new['Numeric code'].astype(str).str.zfill(3)

country_dict = dict(zip(df_new['Numeric code'], df_new['Alpha-3 code']))

print(country_dict['004'])
# Out:
# AFG
# <ipython-input-10-af15affc98e4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['Numeric code'] = df_new['Numeric code'].str.strip().str.replace('"', '')
# <ipython-input-10-af15affc98e4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['Alpha-3 code'] = df_new['Alpha-3 code'].str.strip().str.replace('"', '')
# <ipython-input-10-af15affc98e4>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import json
with open("conversion_numeric.json", "w") as json_file:
    json.dump(country_dict, json_file, indent=4)
